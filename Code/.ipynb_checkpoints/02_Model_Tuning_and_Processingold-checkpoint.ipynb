# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 100
pd.options.display.max_columns = 3000

# %% [markdown]
# # Load and Merge Data

# %%
cd ../..

# %%
train = pd.read_csv('./datasets/train.csv')
test = pd.read_csv('./datasets/test.csv')

# %%
def merge_files(train, test):
    
    # Add source column to train data
    train['source'] = 'train'
    
    #Add Sale price and source to test data
    test['SalePrice'] = 0
    test['source'] = 'test'
    
    # Merge train and test
    final = pd.concat([train, test])
    
    # Update the headings of the final dataset
    new_columns_dict = {c: c.replace(' ', '_').lower() for c in df.columns} #lowercase all column headings
    final.rename(columns = new_columns_dict, inplace = True)
    
    return final

# %%
def sep_data(df):
    train = df[df['source'] == 'train']
    train.drop('source', axis=1, inplace=True)
    test = df[df['source'] == 'test']
    test.drop(['source', 'saleprice'], axis=1, inplace=True)

# %%
def evaluate_model(model, X, y):
    print(f'R2 Score: {r2_score(y, model.predict(X))}')
    print(f'MSE: {mean_squared_error(y, model.predict(X))}')
    print(f'RMSE: {np.sqrt(mean_squared_error(y, model.predict(X)))}')

# %%
def scale_model(X, y):

# %%
def linear_model(X_train, y_train):
    lr = LinearRegression()
    lr.fit(X_train, y_train)

# %%
def add_dummies(df, dummy_list):
    df = pd.get_dummies(columns=dummy_list, drop_first=True, data=df) #drop_first=True, drops the first column

# %%
def save_output(testset, output_file):
    pred_price = lr.predict(testset)
    test['y_hat'] = lr.predict(testset)
    submission = pd.DataFrame({'id': test['id'],
                            'SalePrice': test['y_hat']})
    submission.to_csv(output_file, index = False)

# %%
train
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
# ...

# %%
df = merge_files(train, test)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-3b3cc760b1e8> in <module>
# ----> 1 df = merge_files(train, test)
#       2 df
#
# <ipython-input-34-2fc2ad09cce1> in merge_files(train, test)
#      12
#      13     # Update the headings of the final dataset
# ---> 14     new_columns_dict = {c: c.replace(' ', '_').lower() for c in df.columns} #lowercase all column headings
#      15     final.rename(columns = new_columns_dict, inplace = True)
#      16
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
load_and_merge()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-99329bbb93a9> in <module>
# ----> 1 load_and_merge()
#
# <ipython-input-2-0202113ec530> in load_and_merge()
#       1 def load_and_merge():
# ----> 2     df = pd.read_csv('../datasets/train.csv')
#       3     test = pd.read_csv('../datasets/test.csv')
#       4
#       5     # Add source column to train data
#
# ...

# %%
plt.figure(figsize=(15, 10))

sns.heatmap(df.corr()[['saleprice']].sort_values('saleprice'),
            annot=True,
            vmin=-1,
            vmax=1,
            cmap='coolwarm');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0d5c1f34c671> in <module>
# ----> 1 plt.figure(figsize=(15, 10))
#       2
#       3 sns.heatmap(df.corr()[['saleprice']].sort_values('saleprice'),
#       4             annot=True,
#       5             vmin=-1,
#
# NameError: name 'plt' is not defined

# %%
sns.pairplot(df, y_vars=['saleprice'], x_vars=["lot_area", "street", "lot_shape", "yr_sold", "condition_1", "neighborhood"]);
